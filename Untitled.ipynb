# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("TesteModelo").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/19 15:24:36 WARN Utils: Your hostname, leonel-cassule, resolves to a loopback address: 127.0.1.1; using 192.168.1.80 instead (on interface wlo1)
# 26/04/19 15:24:36 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/19 15:24:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv("datasets/retail-data.csv", sep=";", header=True, inferSchema=True)

# %%
df_filtered = df.filter(df.Quantity > 5)

# %%
df.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- Country: string (nullable = true)

# %%
df_filtered.show(20)
# Out:
# +---------+---------+--------------------+--------+----------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+----------------+---------+----------+--------------+
# |   536375|    71053| WHITE METAL LANTERN|       6|01/12/2010 09:32|     3.39|     17850|United Kingdom|
# |   536395|    21314|SMALL GLASS HEART...|       8|01/12/2010 10:47|      2.1|     13767|United Kingdom|
# |   536396|   82494L|WOODEN FRAME ANTI...|      12|01/12/2010 10:51|     2.55|     17850|United Kingdom|
# |   536425|    22837|HOT WATER BOTTLE ...|       8|01/12/2010 12:08|     4.65|     13758|United Kingdom|
# |   536530|    21071|VINTAGE BILLBOARD...|      24|01/12/2010 13:21|     1.25|     17905|        France|
# |   536575|   15056P|EDWARDIAN PARASOL...|      48|01/12/2010 16:01|      4.6|     13777|United Kingdom|
# ...
