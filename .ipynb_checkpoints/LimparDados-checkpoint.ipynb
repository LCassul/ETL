# %%
# import sparksession

from pyspark.sql import SparkSession

#Inition  SparkSession

spark = SparkSession.builder.appName("LimparDados").getOrCreate()
# Out:
# 26/04/03 22:03:56 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
