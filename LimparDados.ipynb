# %%
# import sparksession

from pyspark.sql import SparkSession

#Inition  SparkSession

spark = SparkSession.builder.appName("LimparDados").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/13 22:50:55 WARN Utils: Your hostname, leonel-cassule, resolves to a loopback address: 127.0.1.1; using 192.168.1.80 instead (on interface wlo1)
# 26/04/13 22:50:55 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/13 22:51:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read Dataframe IOT
df_iot = spark.read.csv(
    "datasets/iot-devices.csv",
    header =  True,
    inferSchema = True,
    sep =  ";"
    
)

# Read Dataframe IOT
df_calls = spark.read.csv(
    "datasets/sf-fire-calls.csv",
    header =  True,
    inferSchema = True,
    
)

# %%
#verifique se há linhas duplicadas ou não

df_iot_no_dup = df_iot.dropDuplicates()

print(f"Numero de linha não duplicada :{df_iot_no_dup.count()}")

#df_iot_no_dup.describe().show(3)
# Out:
# [Stage 4:=========>                                                 (1 + 5) / 6]
# Numero de linha não duplicada :198164

# %%
# Valores nulos existentes
#null_calls = df_calls.isNull().sum() 
#print(null_calls)
